# %%
import json
import os
filename = os.listdir('./logs')[-1]

f = open('logs/' + filename, 'r')
data = f.read()
data
# Out:
# '{"1707510504248": {\'POSITION(0x001)\': 1.3083953857421875, \'VELOCITY(0x002)\': -0.010513496585190296, \'TORQUE(0x003)\': 0.0, \'VOLTAGE(0x00d)\': 24.0, \'TEMPERATURE(0x00e)\': 42.0, \'FAULT(0x00f)\': 0.0}"1707510504275": {\'POSITION(0x001)\': 1.308258056640625, \'VELOCITY(0x002)\': -0.013462712988257408, \'TORQUE(0x003)\': -0.011781720444560051, \'VOLTAGE(0x00d)\': 24.0, \'TEMPERATURE(0x00e)\': 42.0, \'FAULT(0x00f)\': 0.0}"1707510504302": {\'POSITION(0x001)\': 1.306640625, \'VELOCITY(0x002)\': -0.15055252611637115, \'TORQUE(0x003)\': -0.03866684064269066, \'VOLTAGE(0x00d)\': 24.0, \'TEMPERATURE(0x00e)\': 42.0, \'FAULT(0x00f)\': 0.0}"1707510504330": {\'POSITION(0x001)\': 1.2955474853515625, \'VELOCITY(0x002)\': -0.609752893447876, \'TORQUE(0x003)\': -0.03808289393782616, \'VOLTAGE(0x00d)\': 24.0, \'TEMPERATURE(0x00e)\': 42.0, \'FAULT(0x00f)\': 0.0}"1707510504355": {\'POSITION(0x001)\': 1.2735137939453125, \'VELOCITY(0x002)\': -0.9279545545578003, \'TORQUE(0x003)\': -0.0178498607128
# ...

# %%
data
# Out:
# '{"1707510504248": {\'POSITION(0x001)\': 1.3083953857421875, \'VELOCITY(0x002)\': -0.010513496585190296, \'TORQUE(0x003)\': 0.0, \'VOLTAGE(0x00d)\': 24.0, \'TEMPERATURE(0x00e)\': 42.0, \'FAULT(0x00f)\': 0.0}"1707510504275": {\'POSITION(0x001)\': 1.308258056640625, \'VELOCITY(0x002)\': -0.013462712988257408, \'TORQUE(0x003)\': -0.011781720444560051, \'VOLTAGE(0x00d)\': 24.0, \'TEMPERATURE(0x00e)\': 42.0, \'FAULT(0x00f)\': 0.0}"1707510504302": {\'POSITION(0x001)\': 1.306640625, \'VELOCITY(0x002)\': -0.15055252611637115, \'TORQUE(0x003)\': -0.03866684064269066, \'VOLTAGE(0x00d)\': 24.0, \'TEMPERATURE(0x00e)\': 42.0, \'FAULT(0x00f)\': 0.0}"1707510504330": {\'POSITION(0x001)\': 1.2955474853515625, \'VELOCITY(0x002)\': -0.609752893447876, \'TORQUE(0x003)\': -0.03808289393782616, \'VOLTAGE(0x00d)\': 24.0, \'TEMPERATURE(0x00e)\': 42.0, \'FAULT(0x00f)\': 0.0}"1707510504355": {\'POSITION(0x001)\': 1.2735137939453125, \'VELOCITY(0x002)\': -0.9279545545578003, \'TORQUE(0x003)\': -0.0178498607128
# ...

# %%
data = [str.replace(',','').replace(':','').replace('}','').split(' ')[0::2] for str in data.split('\n')]

# %%
str.replace(',','').replace(':','').replace('}','').replace('{','').split(' ')[0::2]
# time, pos, vel, torque, temperature
# Out:
# ['']

# %%
data
# Out:
# [['{"1707510504248"',
#   '1.3083953857421875',
#   '-0.010513496585190296',
#   '0.0',
#   '24.0',
#   '42.0',
#   '0.0"1707510504275"',
#   '1.308258056640625',
#   '-0.013462712988257408',
#   '-0.011781720444560051',
#   '24.0',
#   '42.0',
#   '0.0"1707510504302"',
#   '1.306640625',
#   '-0.15055252611637115',
#   '-0.03866684064269066',
#   '24.0',
#   '42.0',
#   '0.0"1707510504330"',
#   '1.2955474853515625',
#   '-0.609752893447876',
#   '-0.03808289393782616',
#   '24.0',
#   '42.0',
#   '0.0"1707510504355"',
#   '1.2735137939453125',
#   '-0.9279545545578003',
#   '-0.017849860712885857',
#   '24.0',
#   '42.0',
#   '0.0"1707510504378"',
#   '1.2511444091796875',
#   '-0.9840654134750366',
#   '-0.014692584984004498',
#   '24.0',
#   '42.0',
#   '0.0"1707510504401"',
#   '1.2287750244140625',
#   '-1.0200080871582031',
#   '-0.029370905831456184',
#   '24.0',
#   '42.0',
#   '0.0"1707510504424"',
#   '1.2004852294921875',
#   '-1.39378821849823',
# ...
